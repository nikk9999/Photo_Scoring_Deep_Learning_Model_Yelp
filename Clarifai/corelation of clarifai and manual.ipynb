# %%
import pandas as pd
import os
import shutil
import glob

# %%
samP = pd.read_csv('/Users/negar/Desktop/groundTruthtestLabels.csv' ,  encoding="utf8")
samP['Info2'] = samP['Info2'].astype(float)


samP.head()
# Out:
#    Unnamed: 0                photo_id             business_id  \
# 0        1124  _15wZGb3QONopTo5yiZ8Rg  ZDDzKXN_JXe7694zePRuTQ
# 1        1142  _80kyh9A5cFNG-RwwDR6iA  1qwkbN3wu3AGDxMTXVz2gA
# 2        1177  _8B40xRtabQop1QXbpGTtA  TKp9PDs8jFbshfg6xOcM6A
# 3        1107  _8tN02g8wArjtdcu1e7Fnw  wPiRP76arN0NB3M1ZXXp7g
# 4         576  _a1d3bupKZ0bzKyUAUmh9w  JhRxDdmZSGDG_u7cGxaYrw
#
#                       caption    label  Good2  Info2  Label2
# 0                     Seating   inside      1    1.0       1
# 1  Sunset from the front door  outside      1    0.0       0
# 2                         NaN     food      1    1.0       1
# 3                         NaN   inside      0    0.0       0
# 4                         NaN  outside      0    1.0       0

# %%
photoIDs = samP['photo_id'].tolist()
groundTruth = samP['Info2'].tolist()
category = samP['label'].tolist()

# %%
cFile = pd.read_csv('/Users/negar/Desktop/analysisClarifai.csv' ,  encoding="utf8" )
cFile.head()
# Out:
#                   photoId      food  drink  indoors  outdoors  restaurant  \
# 0  5V7TdipB7U2nUu6wrJh71w  0.000000    0.0      0.0  0.952767    0.000000
# 1  27H-FJTwH_QJFqVUEcGXzg  0.993639    0.0      0.0  0.000000    0.958397
# 2  _TM-Dvt3qRoNVaMFylBXyA  0.990979    0.0      0.0  0.000000    0.969926
# 3  5RbtCqVvFTnOPAeV4yI1og  0.991222    0.0      0.0  0.000000    0.958433
# 4  loh3-FSJhTQJdl0YLF-rIQ  0.990084    0.0      0.0  0.000000    0.000000
#
#    people  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0     0.0         NaN         NaN         NaN          NaN          NaN
# 1     0.0         NaN         NaN         NaN          NaN          NaN
# 2     0.0         NaN         NaN         NaN          NaN          NaN
# 3     0.0         NaN         NaN         NaN          NaN          NaN
# 4     0.0         NaN         NaN         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13  label
# 0          NaN          NaN      0
# ...

# %%
clarifaiPhotoId = cFile['photoId'].tolist()
cFile['food'] = cFile['food'].astype(float)
clarifaiVal = cFile['food'].tolist()

# %%
total = 0
correct = 0
falseNegative=0
falsePositive = 0
falsePIds = []
trueNegative = 0

truePositive=0



path = '/Users/negar/Documents/FALL 2018/Big Data/labeledYelp/'
for i in range (0,len(clarifaiPhotoId)):
    if clarifaiPhotoId[i] in photoIDs:
        
        index = photoIDs.index(clarifaiPhotoId[i])
        
        total = total + 1
        if clarifaiVal[i]>0.8:
            clarifaiVal[i] = 1
        else:
            clarifaiVal[i] = 0
        if groundTruth[index] == (clarifaiVal[i]):
            correct  = correct  + 1
            if groundTruth[index] == 1:
                truePositive  = truePositive  + 1 
                #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/truepositive/')
            elif groundTruth[index] == 0:
                #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/trueNeg/')
                trueNegative  = trueNegative  + 1
                #falsePIds.append(photoIDs[index])
        else:
            print(photoIDs[index] + "   " + str(groundTruth[index])+"   " + str(clarifaiVal[i])+ "   "+category[index])
            if groundTruth[index] == 1:
                falseNegative  = falseNegative  + 1 
                #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/falseNeg/')
            elif groundTruth[index] == 0:
                #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/falsepositive/')
                falsePositive  = falsePositive  + 1
                #falsePIds.append(photoIDs[index])
# Out:
# 4fhQdcABwN0SpD9Lw5bQBQ   1.0   0   inside
# mZQzty5VG9Bp0hp22n_7Ug   0.0   1   inside
# nd0fTe86dIzViNRSwyXvWg   1.0   0   inside
# 7N_7QmfQZOjs-QcnJdBdNg   1.0   0   inside
# 4yODrsY9ctPzDpEZ4Cxyig   0.0   1   inside
# KQ9DpXOFoaswwEho7a8IbA   1.0   0   inside
# mGTj3r3F4jGSPiBIzeiCxQ   1.0   0   outside
# k2g5_7dCq_ZOqOarHk8Q5g   1.0   0   inside
# 4FMVvay0veBDVdcP6IOBVg   1.0   0   inside
# OnQvHUKxCajAiZGG5hejqQ   0.0   1   inside
# K-u5VRkAL1oxYrhmA6fNpg   0.0   1   inside
# 1ibhUpxOALUb7c9HisHjIw   0.0   1   inside
# mVAfFeCPbFG-wkEU8odwMQ   1.0   0   inside
# _Yu1jEA8xjRICta4JNLmpg   1.0   0   drink
# nta1zZuaXXV5tXpXnIDwzA   1.0   0   inside
# _mM3GMsJnxacanUk4waIzw   1.0   0   inside
# lCUkdRVoXooTmO80cOUOAQ   1.0   0   inside
# Lnfo687qPmVXE5p3YoKr-w   1.0   0   inside
# -TdX8PBidQ3Qx5Ddj_kYTA   1.0   0   inside
# 1s9Q_w_mt6wnxHwYxIT2zw   1.0   0   inside
# oLdv2eoe7ExsQ2R5SgfcZQ   1.0   0   inside
# LQ4TSHyfCdioMr0aWOXbnQ   0.0   1   inside
# ...

# %%
print("accuracy:  "+str(round(correct /total ,3)))
print('precision:   '+str(truePositive /(truePositive +falsePositive )) )
print('recall:   '+str(truePositive /(truePositive +falseNegative )) )
# Out:
# accuracy:  0.883
# precision:   0.9301675977653632
# recall:   0.904891304347826

# %%
total = 0
correct = 0
falseNegative=0
falsePositive = 0
falsePIds = []

total_food = 0
falseNegative_food = 0
falsePositive_food = 0
correct_food = 0
trueNegative_food = 0
truePositive_food = 0

total_inside = 0
falseNegative_inside = 0
falsePositive_inside = 0
correct_inside = 0
trueNegative_inside = 0
truePositive_inside = 0



total_outside = 0
falseNegative_outside = 0
falsePositive_outside = 0
correct_outside = 0
trueNegative_outside = 0
truePositive_outside = 0



total_drink = 0
falseNegative_drink = 0
falsePositive_drink = 0
correct_drink = 0
trueNegative_drink = 0
truePositive_drink = 0




path = '/Users/negar/Documents/FALL 2018/Big Data/labeledYelp/'
for i in range (0,len(clarifaiPhotoId)):
    if clarifaiPhotoId[i] in photoIDs:
        index = photoIDs.index(clarifaiPhotoId[i])
        if category[index] == 'food':
            total_food = total_food + 1
        
            if groundTruth[index] == (clarifaiVal[i]):
                correct_food = correct_food + 1
                if groundTruth[index] == 1:
                    truePositive_food = truePositive_food + 1 
                    #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/truepositive/')
                elif groundTruth[index] == 0:
                    #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/trueNeg/')
                    trueNegative_food = trueNegative_food + 1
                    #falsePIds.append(photoIDs[index])
            else:
                print(photoIDs[index] + "   " + str(groundTruth[index])+"   " + str(clarifaiVal[i])+ "   "+category[index])
                if groundTruth[index] == 1:
                    falseNegative_food = falseNegative_food + 1 
                    #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/falseNeg/')
                elif groundTruth[index] == 0:
                    #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/falsepositive/')
                    falsePositive_food = falsePositive_food + 1
                    #falsePIds.append(photoIDs[index])
                    
        if category[index] == 'inside':
            total_inside = total_inside + 1
            if groundTruth[index] == (clarifaiVal[i]):
                correct_inside = correct_inside + 1
                if groundTruth[index] == 1:
                    truePositive_inside = truePositive_inside + 1 
                    #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/truepositive/')
                elif groundTruth[index] == 0:
                    #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/trueNeg/')
                    trueNegative_food = trueNegative_food + 1
                    #falsePIds.append(photoIDs[index])
            else:
                print(photoIDs[index] + "   " + str(groundTruth[index])+"   " + str(clarifaiVal[i])+ "   "+category[index])
                if groundTruth[index] == 1:
                    falseNegative_inside = falseNegative_inside + 1 
                    #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/falseNeg/')
                elif groundTruth[index] == 0:
                    #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/falsepositive/')
                    falsePositive_inside = falsePositive_inside + 1
                    #falsePIds.append(photoIDs[index])
        
        if category[index] == 'outside':
            total_outside = total_outside + 1
            if groundTruth[index] == (clarifaiVal[i]):
                correct_outside = correct_outside + 1
                if groundTruth[index] == 1:
                    truePositive_outside = truePositive_outside+ 1 
                    #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/truepositive/')
                elif groundTruth[index] == 0:
                    #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/trueNeg/')
                    trueNegative_outside = trueNegative_outside + 1
                    #falsePIds.append(photoIDs[index])
            else:
                print(photoIDs[index] + "   " + str(groundTruth[index])+"   " + str(clarifaiVal[i])+ "   "+category[index])
                if groundTruth[index] == 1:
                    falseNegative_outside = falseNegative_outside + 1 
                    #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/falseNeg/')
                elif groundTruth[index] == 0:
                    #shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/falsepositive/')
                    falsePositive_outside = falsePositive_outside + 1
                    #falsePIds.append(photoIDs[index])
                    
        if category[index] == 'drink':
            total_drink = total_drink + 1
            if groundTruth[index] == (clarifaiVal[i]):
                correct_drink = correct_drink + 1
                if groundTruth[index] == 1:
                    truePositive_drink = truePositive_drink+ 1 
                    shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/truepositive/')
                elif groundTruth[index] == 0:
                    shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/trueNeg/')
                    trueNegative_drink = trueNegative_drink + 1
                    #falsePIds.append(photoIDs[index])
            else:
                print(photoIDs[index] + "   " + str(groundTruth[index])+"   " + str(clarifaiVal[i])+ "   "+category[index])
                if groundTruth[index] == 1:
                    falseNegative_drink = falseNegative_drink + 1 
                    shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/falseNeg/')
                elif groundTruth[index] == 0:
                    shutil.copy(path+clarifaiPhotoId[i]+".jpg",'/Users/negar/Desktop/analysis/falsepositive/')
                    falsePositive_drink = falsePositive_drink + 1
                    #falsePIds.append(photoIDs[index])
# Out:
# 4h3HDVkWRnnZzlprGsCvBg   1.0   0   food
# 0YsGgoecQ4-xv4d3hIaX-Q   0.0   1   inside
# 6HzabYbNfAtDa01SdrtD1Q   0.0   1   inside
# O96UwAf-mmmkQoI9fL3enA   0.0   1   inside
# jJpRSc5m1t6Wt4PZfIl2Tg   1.0   0   food
# mGTj3r3F4jGSPiBIzeiCxQ   1.0   0   outside
# nI9u5UXtlwlZUAFGrcZwbA   0.0   1   inside
# -qfhVTtCpHny2ttc4XkcKw   0.0   1   inside
# OnQvHUKxCajAiZGG5hejqQ   0.0   1   inside
# 9tE1VWVEDENNDGYsbCMfIw   1.0   0   food
# NWTnImwich2GUOSVKxkb5g   0.0   1   inside
# mVAfFeCPbFG-wkEU8odwMQ   1.0   0   inside
# M68f-ZiQsrsEsldqx9-ABg   1.0   0   food
# nta1zZuaXXV5tXpXnIDwzA   1.0   0   inside
# 1xcAwb9McEL9oWdUu6vBxw   1.0   0   food
# _mM3GMsJnxacanUk4waIzw   1.0   0   inside
# JlDokWSBsoYYbCfgfP6xlw   0.0   1   outside
# 0T2uBcCmVG_iBqKb5L3dBA   0.0   1   inside
# 3XXI4WvZHmNjPcYw1k_p7g   1.0   0   food
# -TdX8PBidQ3Qx5Ddj_kYTA   1.0   0   inside
# LsQUN0rGpVZ6CLyCUtvX3g   0.0   1   inside
# 4WZkf7q7caKqNH6tBEXGCA   1.0   0   inside
# ...

# %%
print(total_food)
print(falseNegative_food) 
print(falsePositive_food) 
print(correct_food)
print(trueNegative_food)
print(truePositive_food)
# Out:
# 319
# 9
# 2
# 308
# 4
# 304

# %%
print(total_inside)
print(falseNegative_inside) 
print(falsePositive_inside) 
print(correct_inside)
print(trueNegative_inside)
print(truePositive_inside)
# Out:
# 125
# 10
# 18
# 97
# 0
# 25

# %%
print(total_outside)
print(falseNegative_outside) 
print(falsePositive_outside) 
print(correct_outside)
print(trueNegative_outside)
print(truePositive_outside)
# Out:
# 48
# 3
# 4
# 41
# 40
# 1

# %%
print(total_drink)
print(falseNegative_drink) 
print(falsePositive_drink) 
print(correct_drink)
print(trueNegative_drink)
print(truePositive_drink)
# Out:
# 18
# 0
# 1
# 17
# 1
# 16

# %%
print("accuracy:  "+str(round(correct_food/total_food,3)))
print('precision:   '+str(truePositive_food/(truePositive_food+falsePositive_food)) )
print('recall:   '+str(truePositive_food/(truePositive_food+falseNegative_food)) )
# Out:
# accuracy:  0.966
# precision:   0.9934640522875817
# recall:   0.9712460063897763

# %%
print("accuracy:  "+str(correct_inside/total_inside))
print('precision:   '+str(truePositive_inside/(truePositive_inside+falsePositive_inside)) )
print('recall:   '+str(truePositive_inside/(truePositive_inside+falseNegative_inside)) )
# Out:
# accuracy:  0.776
# precision:   0.5813953488372093
# recall:   0.7142857142857143

# %%
print("accuracy:  "+str(correct_outside/total_outside))
print('precision:   '+str(truePositive_outside/(truePositive_outside+falsePositive_outside)) )
print('recall:   '+str(truePositive_outside/(truePositive_outside+falseNegative_outside)) )
# Out:
# accuracy:  0.8541666666666666
# precision:   0.2
# recall:   0.25

# %%
print("accuracy:  "+str(correct_drink/total_drink))
print('precision:   '+str(truePositive_drink/(truePositive_drink+falsePositive_drink)) )
print('recall:   '+str(truePositive_drink/(truePositive_drink+falseNegative_drink)) )
# Out:
# accuracy:  0.9444444444444444
# precision:   0.9411764705882353
# recall:   1.0

# %%
print(total)
print(correct)
# Out:
# 511
# 464

# %%
cols = [1,2,3,4,5,6,7]
for col in cols:
    cFile[col] = cFile[col].astype(float)
clarifaiPhotoId = cFile[0].tolist()
clarifaiVal = cFile[7].tolist()
foodVal = cFile[1].tolist()
drinkVal = cFile[2].tolist()
indoorVal = cFile[3].tolist()
outdoorVal = cFile[4].tolist()
restVal = cFile[5].tolist()
peopleVal = cFile[6].tolist()
cFile.head()
# Out:
#                         0         1    2    3         4         5    6    7
# 1  5V7TdipB7U2nUu6wrJh71w  0.000000  0.0  0.0  0.952767  0.000000  0.0  1.0
# 2  27H-FJTwH_QJFqVUEcGXzg  0.993639  0.0  0.0  0.000000  0.958397  0.0  1.0
# 3  _TM-Dvt3qRoNVaMFylBXyA  0.990979  0.0  0.0  0.000000  0.969926  0.0  1.0
# 4  5RbtCqVvFTnOPAeV4yI1og  0.991222  0.0  0.0  0.000000  0.958433  0.0  1.0
# 5  loh3-FSJhTQJdl0YLF-rIQ  0.990084  0.0  0.0  0.000000  0.000000  0.0  1.0

# %%
newVal = []
for i in range (0,len(clarifaiPhotoId)):
    informative = max(foodVal[i],drinkVal[i],indoorVal[i],outdoorVal[i])
    if informative == indoorVal[i] or informative==outdoorVal[i]:
        if restVal[i]<0.9:
            informative = 0
    if informative>peopleVal[i] and informative>=0.9 and peopleVal[i]<0.95:
       newVal.append(1)
    else:
       newVal.append(0)
    
clarifaiVal = newVal
for i in range (0,len(clarifaiVal)):
    clarifaiVal[i] = float(clarifaiVal[i])

# %%
print(falsePositive)
print(falseNegative)
# Out:
# 25
# 22

# %%
display(cFile)
# Out:
#                           0         1         2         3         4         5  \
# 1    5V7TdipB7U2nUu6wrJh71w  0.000000  0.000000  0.000000  0.952767  0.000000
# 2    27H-FJTwH_QJFqVUEcGXzg  0.993639  0.000000  0.000000  0.000000  0.958397
# 3    _TM-Dvt3qRoNVaMFylBXyA  0.990979  0.000000  0.000000  0.000000  0.969926
# 4    5RbtCqVvFTnOPAeV4yI1og  0.991222  0.000000  0.000000  0.000000  0.958433
# 5    loh3-FSJhTQJdl0YLF-rIQ  0.990084  0.000000  0.000000  0.000000  0.000000
# 6    0xdP0HX_LhbQJKVLio8Eig  0.000000  0.000000  0.836562  0.000000  0.000000
# 7    MUIpOCyz4a_5y2Q3DTDAMw  0.997653  0.000000  0.000000  0.000000  0.964782
# 8    kMfOYixcnypCH5-fDp0fYA  0.996503  0.000000  0.000000  0.000000  0.962879
# 9    nRF-3c5yQr_3qfsKI178ug  0.994912  0.000000  0.000000  0.000000  0.000000
# 10   7AbXCwENEOMgFxzslqNe2g  0.000000  0.000000  0.934019  0.000000  0.939371
# 11   5rMURL_HZtYlVgNilqJjXA  0.985421  0.930804  0.963141  0.000000  0.923525
# ...

# %%
path = '/Users/negar/Desktop/BigData/test/informative/'

for filename in os.listdir(path):
    if (os.path.splitext(filename)[0] in falsePIds):
        shutil.copy(path+filename,'/Users/negar/Desktop/BigData/falsePositiveTest/')

# %%
testData = pd.read_csv('/Users/negar/Desktop/BigData/Book5.csv' ,  encoding="utf8" )
testData.head()
# Out:
#                   photoId      food  drink  indoors  outdoors  restaurant  \
# 0  5V7TdipB7U2nUu6wrJh71w  0.000000    0.0      0.0  0.952767    0.000000
# 1  27H-FJTwH_QJFqVUEcGXzg  0.993639    0.0      0.0  0.000000    0.958397
# 2  _TM-Dvt3qRoNVaMFylBXyA  0.990979    0.0      0.0  0.000000    0.969926
# 3  5RbtCqVvFTnOPAeV4yI1og  0.991222    0.0      0.0  0.000000    0.958433
# 4  loh3-FSJhTQJdl0YLF-rIQ  0.990084    0.0      0.0  0.000000    0.000000
#
#    people  label
# 0     0.0      1
# 1     0.0      1
# 2     0.0      1
# 3     0.0      1
# 4     0.0      1

# %%
newdf = 
for index, row in testData.iterrows():
    if(row['photoId'] not in falsePIds ):
        testData = testData.drop(testData.index[index])
# Out:
# -------------------------------------------------------
# IndexError            Traceback (most recent call last)
# <ipython-input-8-8f4f26f68816> in <module>()
#       1 for index, row in testData.iterrows():
#       2     if(row['photoId'] not in falsePIds ):
# ----> 3         testData = testData.drop(testData.index[index])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    2067
#    2068         if is_scalar(key):
# -> 2069             return getitem(key)
#    2070
#    2071         if isinstance(key, slice):
#
# IndexError: index 250 is out of bounds for axis 0 with size 250

# %%
display(testData)
# Out:
#                     photoId      food     drink   indoors  outdoors  \
# 0    5V7TdipB7U2nUu6wrJh71w  0.000000  0.000000  0.000000  0.952767
# 1    27H-FJTwH_QJFqVUEcGXzg  0.993639  0.000000  0.000000  0.000000
# 444  ofgx7pDrZA8BR25d_d71Qg  0.000000  0.000000  0.000000  0.000000
# 445  k2Cyn7nggEO9sQNJ3DM79g  0.941080  0.992905  0.981065  0.842099
# 446  KcV3MAv_5NI43SZq3HzO_g  0.993113  0.000000  0.000000  0.000000
# 447  2NmQVx3NgRxG52Blx_haCA  0.997519  0.000000  0.000000  0.000000
# 448  5OPOhyHNVIBp91_qHuofvQ  0.000000  0.000000  0.924311  0.000000
# 449  60Lplu6du9OBx66BZ1GcrA  0.984055  0.000000  0.000000  0.000000
# 450  7kSbz00Lvw-4e8hGcimdBw  0.949445  0.993209  0.000000  0.000000
# 451  jzc4UQcPLB6HvgJyV6ybSQ  0.990682  0.000000  0.000000  0.000000
# 452  3wweKaxI9_1ovaaqp_ZKmw  0.983357  0.982842  0.886834  0.000000
# 453  mYf5YwI9euz7Qli5_Y8HZw  0.962306  0.915276  0.974279  0.000000
# 454  _RS-CoIEPsTLXMu1OvfE0A  0.995486  0.000000  0.000000  0.000000
# ...

# %%
print(falseNegative)
print(falsePositive)
# Out:
# 22
# 44
